# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import Levenshtein as L

# %%
df = pd.DataFrame( { 'a' : [1, 2, 1, 2], 'b': [ 'x', 'x', 'y', 'y'] })
df['value'] = df.apply(lambda row: str(row.a) + ' + ' + row.b, axis=1)
df
# Out:
#    a  b  value
# 0  1  x  1 + x
# 1  2  x  2 + x
# 2  1  y  1 + y
# 3  2  y  2 + y

# %%
df.pivot(index='a', columns='b', values='value')
# Out:
# b      x      y
# a
# 1  1 + x  1 + y
# 2  2 + x  2 + y

# %% [markdown]
# ### Question 1:
#
#  find out what class Alice got an A in?

# %%
Students = pd.DataFrame({'student_id': [1, 2], 'name': ['Alice', 'Bob']})
Grades = pd.DataFrame({'student_id': [1, 1, 2, 2], 'class_id': [1, 2, 1, 3],
                       'grade': ['A', 'C', 'B', 'B']})
Classes = pd.DataFrame({'class_id': [1, 2, 3], 'title': ['Math', 'English', 'Spanish']})

# %%
Students
# Out:
#     name  student_id
# 0  Alice           1
# 1    Bob           2

# %%
Grades
# Out:
#    class_id grade  student_id
# 0         1     A           1
# 1         2     C           1
# 2         1     B           2
# 3         3     B           2

# %%
Classes
# Out:
#    class_id    title
# 0         1     Math
# 1         2  English
# 2         3  Spanish

# %%
tmp1= pd.merge(Students[Students['name']=='Alice'],Grades, on='student_id')
tmp2=pd.merge(tmp1[tmp1['grade']=='A'],Classes,on='class_id')
tmp2['title']
# Out:
# 0    Math
# Name: title, dtype: object

# %% [markdown]
# ### Question 2
#
# Suppose we want to get students' grades for each class in a more straightforward way, and decide to get a Dataframe that:
#
# 1.has one row for each student name,
#
# 2.different class titles as columns names,
#
# 3.the grades of students in different classes as the values (NaN if not applicable).
#
# how do we get such a DataFrame?

# %%
pd.merge(pd.merge(Students,Grades,on='student_id'),
         Classes,on='class_id').pivot(index='name',columns='title',values='grade')
# Out:
# title English Math Spanish
# name
# Alice       C    A     NaN
# Bob       NaN    B       B

# %%
resto=pd.read_csv("/home/datascience/Downloads/restaurants.csv")

# %%
resto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 858 entries, 0 to 857
# Data columns (total 4 columns):
# id         858 non-null int64
# cluster    858 non-null int64
# name       858 non-null object
# city       858 non-null object
# dtypes: int64(2), object(2)

# %%
resto['dummy'] = 0
prod = pd.merge(resto, resto, on='dummy')

# Clean up
del prod['dummy']
del resto['dummy']

# %% [markdown]
# ### Question 3
#
# Remove pairs with the same IDs and redundant pairs in 'prod'.

# %%
prod = prod[prod.id_x > prod.id_y]
prod
# Out:
#         id_x  cluster_x             name_x         city_x  id_y  cluster_y  \
# 2        560        453               2223  san francisco   279        172
# 3        560        453               2223  san francisco    43         23
# 4        560        453               2223  san francisco    44         23
# 5        560        453               2223  san francisco   280        173
# 6        560        453               2223  san francisco   486        379
# 7        560        453               2223  san francisco   145         74
# 8        560        453               2223  san francisco   146         74
# 7                                     abruzzi        atlanta
# 8                                     abruzzi        atlanta
# 10                       adriano's ristorante    los angeles
# 11                                   adrienne       new york
# 13                                  agrotikon       new york
# 14                                        aja       new york
# 15                             alain rondelli  san francisco
# 16                             alain rondelli  san francisco
# 17                                      alamo       new york
# 18                    aleck's barbecue heaven        atlanta
# 19                                alley's end       new york
# 21                           ambassador grill       new york
# 22                             american place       new york
# 23                               anche vivolo       new york
# 25                        annie's thai castle        atlanta
# 26                                   anthonys        atlanta
# 27                                  antonio's      las vegas
# 29                                       aqua  san francisco
# 30                                       aqua  san francisco
# 31                                    aquavit       new york
# 32                                    aquavit  new york city
# 34                                    arizona       new york
# 35                  arnie morton's of chicago    los angeles
# 36                  arnie morton's of chicago    los angeles
# 37                                 art's deli    studio city
# ...                                       ...            ...
# 736119                              valentino   santa monica
# 736122                               venetian      las vegas
# 736123                         veni vidi vici        atlanta
# 736124                  veniero's pasticceria       new york
# 736125                                verbena       new york
# 736126                                vertigo  san francisco
# 736129                          victor's cafe       new york
# 736130                                   vida      los feliz
# 736131                        vince & eddie's       new york
# 736132                               virgil's       new york
# 736133                      virgil's real bbq  new york city
# 736134                         viva mercado's      las vegas
# 736135                      vivande porta via  san francisco
# 736136                     vivande ristorante  san francisco
# 736137                                   vong       new york
# 736139                             water club       new york
# 736141                                   west       new york
# 736142                        west beach cafe    los angeles
# 736147                           world wrapps  san francisco
# 736148                                wu kong  san francisco
# 736149                                  xunta       new york
# 736151                              yank sing  san francisco
# 736152                           yaya cuisine  san francisco
# 736153                                yolie's      las vegas
# 736154                    yoyo tsumami bistro  san francisco
# 736155                          yujean kang's       pasadena
# 736156  yujean kang's gourmet chinese cuisine    los angeles
# 736160                               zarzuela  san francisco
# 736161                             zen palate       new york
# 736162                                    zoe       new york
#
# [367653 rows x 8 columns]

# %%
prod['distance'] = prod.apply(lambda r: L.distance(r['name_x'], r['name_y']), axis=1)

# %%
prod[:10]
# Out:
#     id_x  cluster_x name_x         city_x  id_y  cluster_y  \
# 2    560        453   2223  san francisco   279        172
# 3    560        453   2223  san francisco    43         23
# 4    560        453   2223  san francisco    44         23
# 5    560        453   2223  san francisco   280        173
# 6    560        453   2223  san francisco   486        379
# 7    560        453   2223  san francisco   145         74
# 8    560        453   2223  san francisco   146         74
# 10   560        453   2223  san francisco   219        112
# 11   560        453   2223  san francisco   281        174
# 13   560        453   2223  san francisco   282        175
#
#                   name_y         city_y  distance
# 2                20 mott       new york         6
# 3                21 club       new york         6
# 4                21 club  new york city         6
# 5         9 jones street       new york        14
# 6                  abbey        atlanta         5
# 7                abruzzi        atlanta         7
# 8                abruzzi        atlanta         7
# 10  adriano's ristorante    los angeles        20
# 11              adrienne       new york         8
# 13             agrotikon       new york         9

# %%
clusters = pd.merge(resto, resto, on='cluster')
clusters = clusters[clusters.id_x > clusters.id_y]

# %%
clusters[:10]
# Out:
#     id_x  cluster                     name_x         city_x  id_y  \
# 5     44       23                    21 club  new york city    43
# 11   146       74                    abruzzi        atlanta   145
# 21   185       94             alain rondelli  san francisco   184
# 37   187       95                       aqua  san francisco   186
# 41    46       24                    aquavit  new york city    45
# 47     2        0  arnie morton's of chicago    los angeles     1
# 50     4        1                 art's deli    studio city     3
# 59    48       25                    aureole  new york city    47
# 63   148       75                bacchanalia        atlanta   147
# 78     6        2              bel-air hotel        bel air     5
#
#                        name_y         city_y
# 5                     21 club       new york
# 11                    abruzzi        atlanta
# 21             alain rondelli  san francisco
# 37                       aqua  san francisco
# 41                    aquavit       new york
# 47  arnie morton's of chicago    los angeles
# 50         art's delicatessen    studio city
# 59                    aureole       new york
# 63                bacchanalia        atlanta
# 78              hotel bel-air        bel air

# %%
# %matplotlib inline
import pylab

# %%
def accuracy(max_distance):
    similar = prod[prod.distance < max_distance]
    correct = float(sum(similar.cluster_x == similar.cluster_y))
    precision = correct / len(similar)
    recall = correct / len(clusters)
    return (precision, recall)

thresholds = range(1, 11)
p = []
r = []

for t in thresholds:
    acc = accuracy(t)
    p.append(acc[0])
    r.append(acc[1])

pylab.plot(thresholds, p)
pylab.plot(thresholds, r)
pylab.legend(['precision', 'recall'], loc='upper left')

# %% [markdown]
# ### Question 4
#
# Another common way to visualize the tradeoff between precision and recall is to plot them directly against each other. Create a line plot with precision on one axis and recall on the other (this graph generated is called precision-recall curve). Where are "good" points on the plot, and where are "bad" ones.(use recall as horizontal axis and precision as vertical axis)

# %%
pylab.plot(r,p)
pylab.xlabel('Recall')
pylab.ylabel('Precision')

# %% [markdown]
# ### Question 5
#
# The python Levenshtein library provides another metric of string similarity called "ratio" (use L.ratio(s1, s1)). ratio gives a similarity score between 0 and 1, with higher meaning more similar. Add a column to "prod" with the ratio similarities of the name columns, and redo the precision/recall tradeoff analysis with the new metric. (Note: you will have to alter the accuracy method and the threshold range.) On this data, does Levenshtein.ratio do better than Levenshtein.distance? (Plot the two precision-recall curves together in one graph to compare them)

# %%
prod['ratio'] = prod.apply(lambda r: L.ratio(r['name_x'], r['name_y']), axis=1)

def accuracy_ratio(ratio_t):
    similar = prod[prod.ratio >= ratio_t]
    correct = float(sum(similar.cluster_x == similar.cluster_y))
    precision = correct / len(similar)
    recall = correct / len(clusters)
    return (precision, recall)

thresholds_ratio = pylab.frange(0,1,0.1)
p_r = []
r_r = []

for t in thresholds_ratio:
    acc = accuracy_ratio(t)
    p_r.append(acc[0])
    r_r.append(acc[1])

pylab.plot(thresholds_ratio, p_r)
pylab.plot(thresholds_ratio, r_r)
pylab.plot(r_r,p_r)
pylab.legend(['precision', 'recall','precision-recall'], loc='upper left')
